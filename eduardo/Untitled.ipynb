# %%
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('priv_data_clean.csv')
df2 = pd.read_csv('priv_data_clean_edu.csv')

# %%
df.shape
# Out:
# (64779, 24)

# %%
df2.shape
# Out:
# (63824, 24)

# %%
63824-64779
# Out:
# -955

# %%
df.loc[df['Make'] == 'Vans']
# Out:
# Empty DataFrame
# Columns: [index, Location, Country, Aircraft.damage, Make, Model, Number.of.Engines, Engine.Type, Purpose.of.flight, Total.Fatal.Injuries, Total.Serious.Injuries, Total.Minor.Injuries, Total.Uninjured, Weather.Condition, Total.Passengers, Total.Injured, Percent.Injured, Percent.Uninjured, Percent.Died, Airplane.Type, Event.Day, Event.Month, Event.Month.Name, Event.Year]
# Index: []
#
# [0 rows x 24 columns]

# %%
df2.loc[df['Make'] == 'Vans']
# Out:
# Empty DataFrame
# Columns: [index, Location, Country, Aircraft.damage, Make, Model, Number.of.Engines, Engine.Type, Purpose.of.flight, Total.Fatal.Injuries, Total.Serious.Injuries, Total.Minor.Injuries, Total.Uninjured, Weather.Condition, Event.Day, Event.Month, Event.Month.Name, Event.Year, Total.Passengers, Total.Injured, Percent.Injured, Percent.Uninjured, Percent.Died, Airplane.Type]
# Index: []
#
# [0 rows x 24 columns]

# %%
concatenated = pd.concat([df, df2], keys=['df', 'df2'])
diff_rows = concatenated[concatenated.duplicated(keep=False)]

# %%
diff_rows
# Out:
#         index Location        Country Aircraft.damage              Make  \
# df  0       0       ID  United States       Destroyed           Stinson
#     1       1       CA  United States       Destroyed             Piper
#     2       2       VA  United States       Destroyed            Cessna
#     3       3       CA  United States       Destroyed          Rockwell
#     4       4       MA  United States     Substantial  Mcdonnel Douglas
# ...       ...      ...            ...             ...               ...
# df2 50     50       NY  United States     Substantial            Cessna
#     51     51       MO  United States     Substantial             Piper
#     52     52       IL  United States     Substantial            Cessna
#     53     53       OH  United States     Substantial            Cessna
#     54     54       SC  United States     Substantial            Cessna
#
#             Model  Number.of.Engines    Engine.Type Purpose.of.flight  \
# ...
